# %%
import pyodbc

# %%
con = pyodbc.connect('DSN=hukar')

# %% [markdown]
# ## DSN
# c'est le nom que l'on donne dans MySQL Connector/ODBC Data Source Configuration
# ![odbc_03.PNG](attachment:odbc_03.PNG)

# %%
cursor = con.cursor()
cursor.execute("SELECT * FROM perso")
row = cursor.fetchone()
print(row)
# Out:
# (1, 'michel', None)

# %%
rows = cursor.fetchall()
for row in rows:
    print(row[0], row[1])
# Out:
# 2 Lucienne
# 3 Tatiana
# 4 Robert
# 5 Xavier

# %%
import time
t0 = time.time()
cursor = con.cursor()
q = "Select count(*) as Reccount "
q += "from perso" 
cursor.execute(q)
rows = cursor.
