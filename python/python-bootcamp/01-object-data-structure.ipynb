# %% [markdown]
# # Les Objets et les Structures de données en Python
# ![Screenshot%202020-01-11%20at%2016.44.07.png](attachment:Screenshot%202020-01-11%20at%2016.44.07.png)

# %%
a = {"titi":7,8:"didi"}
print(a[8])
print(a["titi"])
# Out:
# didi
# 7

# %%
b = {"titi", 6, "dede"}
b
# Out:
# {6, 'dede', 'titi'}

# %%
c = {"dede", 5, "toto", 5}
c
# Out:
# {5, 'dede', 'toto'}

# %% [markdown]
# ## Les nombres

# %%
2 // 3
# Out:
# 0

# %%
6 // 4 # division entière
# Out:
# 1

# %%
6 % 4 # modulo
# Out:
# 2

# %% [markdown]
# `//` est l'opérateur de division entière
# `%` est le reste de la division entière (modulo)

# %%
3 ** 4 + 3 ** 2 + 10
# Out:
# 100
